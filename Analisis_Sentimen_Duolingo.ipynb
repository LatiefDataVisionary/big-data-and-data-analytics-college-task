# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/big-data-and-data-analytics-college-task/blob/main/Analisis_Sentimen_Duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Judul Dataset** 	: Duolingo playstore appstore reviews dataset
#
# **Link Dataset**		: https://www.kaggle.com/datasets/rajvardhanshendge/duolingo-playstore-appstore-reviews-dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('aplaystoreappstoreduolingoreviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       source                             review_id  \
# 0           0  Google Play  acd36426-845f-499d-894e-75894944664d
# 1           1  Google Play  de1f3d24-328e-47d2-b8d2-176d3896e156
# 2           2  Google Play  6f7eb9e3-3621-4fd4-ba85-b14b4ac97414
# 3           3  Google Play  cb985479-b8ae-40b4-90e0-1e5fbf31a597
# 4           4  Google Play  747a16db-708d-4318-8001-eb0738580b67
#
#            user_name  review_title  \
# 0  Rajammal munusamy           NaN
# 1        Najlae Jeon           NaN
# 2       Rahul Sawant           NaN
# 3       Ravi Prakash           NaN
# 4          Jack Dean           NaN
#
#                                   review_description  rating  thumbs_up  \
# 0                            I love it and it's easy     5.0        0.0
# 1          This is the best application for learning     5.0        0.0
# 2  it's actually fun, I'm a beginner so I really ...     5.0        0.0
# 3  This is the best app to learn languages. It ma...     5.0        0.0
# 4                    Best app ever SPANISH OR VANISH     5.0        0.0
#
#            review_date  developer_response  developer_response_date  \
# 0  2023-11-15 17:26:28                 NaN                      NaN
# 1  2023-11-15 17:26:04                 NaN                      NaN
# 2  2023-11-15 17:25:14                 NaN                      NaN
# 3  2023-11-15 17:24:45                 NaN                      NaN
# 4  2023-11-15 17:22:36                 NaN                      NaN
#
#   appVersion laguage_code country_code
# 0    5.125.4           en           us
# 1    5.128.3           en           us
# 2    5.128.3           en           us
# 3        NaN           en           us
# 4        NaN           en           us

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376465 entries, 0 to 376464
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               376465 non-null  int64
#  1   source                   376465 non-null  object
#  2   review_id                376465 non-null  object
#  3   user_name                376463 non-null  object
#  4   review_title             0 non-null       float64
#  5   review_description       376463 non-null  object
#  6   rating                   376464 non-null  float64
#  7   thumbs_up                376464 non-null  float64
#  8   review_date              376464 non-null  object
#  9   developer_response       0 non-null       float64
#  10  developer_response_date  0 non-null       float64
#  11  appVersion               336952 non-null  object
#  12  laguage_code             376464 non-null  object
#  13  country_code             376464 non-null  object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 40.2+ MB

# %%
df.describe()
# Out:
#           Unnamed: 0  review_title         rating      thumbs_up  \
# count  376465.000000           0.0  376464.000000  376464.000000
# mean   188232.000000           NaN       4.292031       1.222199
# std    108676.228883           NaN       1.268726      28.007634
# min         0.000000           NaN       1.000000       0.000000
# 25%     94116.000000           NaN       4.000000       0.000000
# 50%    188232.000000           NaN       5.000000       0.000000
# 75%    282348.000000           NaN       5.000000       0.000000
# max    376464.000000           NaN       5.000000    6742.000000
#
#        developer_response  developer_response_date
# count                 0.0                      0.0
# mean                  NaN                      NaN
# std                   NaN                      NaN
# min                   NaN                      NaN
# 25%                   NaN                      NaN
# 50%                   NaN                      NaN
# 75%                   NaN                      NaN
# max                   NaN                      NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# source                          0
# review_id                       0
# user_name                       2
# review_title               376465
# review_description              2
# rating                          1
# thumbs_up                       1
# review_date                     1
# developer_response         376465
# developer_response_date    376465
# appVersion                  39513
# laguage_code                    1
# country_code                    1
# dtype: int64

# %%
display(df.duplicated().sum())
# Out:
# 0

# %%
# Mendapatkan jumlah baris dan kolom
jumlah_baris, jumlah_kolom = df.shape

# Menampilkan jumlah baris dan kolom
print(f"Jumlah baris dalam dataset: {jumlah_baris}")
print(f"Jumlah baris dalam dataset: {jumlah_kolom}")
# Out:
# Jumlah baris dalam dataset: 376465
# Jumlah baris dalam dataset: 14

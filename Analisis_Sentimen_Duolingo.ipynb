# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/big-data-and-data-analytics-college-task/blob/main/Analisis_Sentimen_Duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Judul Dataset** 	: Duolingo playstore appstore reviews dataset
#
# **Link Dataset**		: https://www.kaggle.com/datasets/rajvardhanshendge/duolingo-playstore-appstore-reviews-dataset

# %%
import pandas as pd

# %%
# df = pd.read_csv('aplaystoreappstoreduolingoreviews.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Big Data & Data Analytics/aplaystoreappstoreduolingoreviews.csv')
# Out:
# <ipython-input-14-09db24209e67>:1: DtypeWarning: Columns (4,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Big Data & Data Analytics/aplaystoreappstoreduolingoreviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       source                             review_id  \
# 0           0  Google Play  acd36426-845f-499d-894e-75894944664d
# 1           1  Google Play  de1f3d24-328e-47d2-b8d2-176d3896e156
# 2           2  Google Play  6f7eb9e3-3621-4fd4-ba85-b14b4ac97414
# 3           3  Google Play  cb985479-b8ae-40b4-90e0-1e5fbf31a597
# 4           4  Google Play  747a16db-708d-4318-8001-eb0738580b67
#
#            user_name review_title  \
# 0  Rajammal munusamy          NaN
# 1        Najlae Jeon          NaN
# 2       Rahul Sawant          NaN
# 3       Ravi Prakash          NaN
# 4          Jack Dean          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0                            I love it and it's easy       5        0.0
# 1          This is the best application for learning       5        0.0
# 2  it's actually fun, I'm a beginner so I really ...       5        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589521 entries, 0 to 1589520
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Unnamed: 0               1589521 non-null  int64
#  1   source                   1589521 non-null  object
#  2   review_id                1589521 non-null  object
#  3   user_name                1589516 non-null  object
#  4   review_title             2000 non-null     object
#  5   review_description       1587311 non-null  object
#  6   rating                   1589521 non-null  int64
#  7   thumbs_up                1587521 non-null  float64
#  8   review_date              1589521 non-null  object
#  9   developer_response       126 non-null      object
#  10  developer_response_date  123 non-null      object
#  11  appVersion               1412434 non-null  object
#  12  laguage_code             1589521 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        rating     thumbs_up
# count  1.589521e+06  1.589521e+06  1.587521e+06
# mean   7.927625e+05  4.499267e+00  7.539403e-01
# std    4.588510e+05  1.050211e+00  1.759789e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.953800e+05  4.000000e+00  0.000000e+00
# 50%    7.927600e+05  5.000000e+00  0.000000e+00
# 75%    1.190140e+06  5.000000e+00  0.000000e+00
# max    1.587520e+06  5.000000e+00  6.742000e+03

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# source                           0
# review_id                        0
# user_name                        5
# review_title               1587521
# review_description            2210
# rating                           0
# thumbs_up                     2000
# review_date                      0
# developer_response         1589395
# developer_response_date    1589398
# appVersion                  177087
# laguage_code                     0
# country_code                     0
# dtype: int64

# %%
display(df.duplicated().sum())
# Out:
# 0

# %%
# Mendapatkan jumlah baris dan kolom
jumlah_baris, jumlah_kolom = df.shape

# Menampilkan jumlah baris dan kolom
print(f"Jumlah baris dalam dataset: {jumlah_baris}")
print(f"Jumlah baris dalam dataset: {jumlah_kolom}")
# Out:
# Jumlah baris dalam dataset: 1589521
# Jumlah baris dalam dataset: 14
